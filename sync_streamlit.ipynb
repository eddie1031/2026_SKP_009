# %%
import plotly.express as px
import streamlit as st

# %% [markdown]
# ```python
# fig = px.bar(
#   df,
#   x='..',
#   y='..',
# )
#
# fig.show()
# ```
#
# ```python
# st.bar_chart()
# ```
#
# ```python
# fig = px.bar(
#   df,
#   x='..',
#   y='..',
# )
#
# st.plotly_chart(
#     fig,
#     width='stretch'
# )
# ```
